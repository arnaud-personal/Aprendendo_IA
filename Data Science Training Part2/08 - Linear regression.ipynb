# %% [markdown]
# <h1>REGRESSÃO LINEAR SIMPLES</h1>

# %% [markdown]
# A Regressão Linear é um modelo fundamental de aprendizado supervisionado, usado para prever valores numéricos contínuos com base em uma ou mais variáveis de entrada (features). É um dos métodos mais interpretáveis e rápidos em estatística e machine learning.
#
# <h3>🎯 O que é e qual o objetivo?</h3>
#
# O objetivo da Regressão Linear é encontrar uma relação linear entre as variáveis independentes (X) e a variável dependente (Y):
#
# 𝑦^=𝛽0+𝛽1𝑥1+𝛽2𝑥2+⋯+𝛽𝑛𝑥𝑛
#
# <ul>
#     <li>β são os coeficientes (pesos) aprendidos pelo modelo.</li>
#     <li>x_i são as variáveis de entrada.</li>
#     <li>ŷ é o valor predito.</li>
# </ul>
#
# <h3>✅ Pré-requisitos</h3>
# <ol>
#     <li>Dados supervisionados com variáveis numéricas.</li>
#     <li>Suposição de relação linear entre X e Y.</li>
#     <li>Ausência (ou controle) de multicolinearidade entre os atributos.</li>
#     <li>Erros com distribuição aproximadamente normal e homocedasticidade (variância constante).</li>
# </ol>
#
# <h3>✅ Vantagens</h3>
# <ul>
#     <li>Muito simples, rápida e interpretável.</li>
#     <li>Funciona bem com pequenos conjuntos de dados.</li>
#     <li>Coeficientes indicam influência de cada variável na resposta.</li>
#     <li>Base para modelos mais complexos (ex: regressão regularizada, redes neurais).</li>
# </ul>
#
# <h3>❌ Desvantagens</h3>
# <ul>
#     <li>Pressupõe linearidade — não funciona bem com relações não-lineares.</li>
#     <li>Sensível a outliers.</li>
#     <li>Depende de algumas hipóteses estatísticas para bons resultados.</li>
# </ul>
#
# <h3>💼 Aplicações comuns</h3>
# <ul>
#     <li>📊 Negócios e Economia
#         <ul>
#             <li>Previsão de vendas, preços, demanda.</li>
#             <li>Análise de tendências.</li>
#         </ul>
#     </li>
#     <li>🏘️ Imobiliário
#         <ul>
#             <li>Estimativa de valor de imóveis com base em atributos como localização e tamanho.</li>
#         </ul>
#     </li>
#     <li>🏥 Saúde
#         <ul>
#             <li>Modelos preditivos clínicos: prever pressão arterial, colesterol, etc.</li>
#         </ul>
#     </li>
#     <li>🎓 Educação
#         <ul>
#             <li>Previsão de notas com base em hábitos de estudo, presença, etc.</li>
#         </ul>
#     </li>
# </ul>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from pylab import rcParams

import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import scale

# %%
rcParams['figure.figsize'] = 10, 8

# %% [markdown]
# <h2>Criando dados fictícios</h2>

# %%
rooms = 2*np.random.rand(100,1)+3
price = 265 + 6*rooms + abs(np.random.randn(100,1))

# %% [markdown]
# <h2>Criando o Plot</h2>

# %%
plt.plot(rooms, price, 'o')
plt.xlabel('# of rooms')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %% [markdown]
# <h2>Criando e treinando a regressão linear</h2>

# %%
modelo = LinearRegression()

modelo.fit(rooms, price)
# Out:
# LinearRegression()

# %% [markdown]
# <h2>Obtendo parâmetros e fazendo predições</h2>

# %% [markdown]
# <h3>Coeficiente angular e intercepto</h3>

# %%
# Coeficiente angular (a)
print('Coeficiente (a):', modelo.coef_[0])

# Intercepto (b)
print('Intercepto (b):', modelo.intercept_)
# Out:
# Coeficiente (a): [5.89148975]
# Intercepto (b): [266.35739287]

# %% [markdown]
# <h2>Desempenho do modelo</h2>

# %%
print(f'Desempenho do modelo (R²):  {modelo.score(rooms, price):.2f}')
# Out:
# Desempenho do modelo (R²):  0.97

# %% [markdown]
# <h2>Visualizando o resultado</h2>

# %% [markdown]
# <h3>Obtendo a previsão de preços segundo o modelo</h3>

# %%
price_pred = modelo.predict(rooms)

# %% [markdown]
# <h3>Plot (matplotlib)</h3>

# %%
# Plotando os pontos originais
plt.scatter(rooms, price, color='blue', marker='o' , label='Dados reais')

# Plotando a reta de regressão
plt.plot(rooms, price_pred, color='red', label='Regressão Linear')

plt.title('Regressão Linear Simples')
plt.xlabel('# of rooms')
plt.ylabel('price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <h3>Fazendo predição de um único valor</h3>

# %%
x = int(input('# de ambientes: '))
pred = modelo.predict([[x]])
print(f'Valor para {x} ambientes: {pred[0][0]:.2f}')
# Out:
# # de ambientes:  2
# Valor para 2 ambientes: 278.14
